# %%
import pandas as pd

# %%
from sklearn.preprocessing import StandardScaler

# %%
train_data = pd.read_csv("HEPMASS/all_train.csv")

# %%
test_data = pd.read_csv("HEPMASS/all_test.csv")

# %%
data = train_data.append(test_data)

# %%
data.drop_duplicates()
# Out:
#          # label        f0        f1        f2        f3        f4        f5  \
# 0            1.0 -0.346368  0.416306  0.999236  0.475342  0.427493 -0.005984
# 1            1.0  1.708236 -0.319394 -1.241873 -0.887231 -0.871906 -0.005984
# 2            0.0 -0.360693  1.794174  0.264738 -0.472273 -0.292344 -1.054221
# 3            1.0 -0.377914 -0.103932 -0.649434 -2.125015 -1.643797 -0.005984
# 4            0.0 -0.067436 -0.636762 -0.620166 -0.062551  1.588715 -0.005984
# 5            1.0  0.242002  1.724236 -0.686819 -0.192709 -0.598296  1.574625
# 6            0.0  2.204765  0.283621 -0.222577 -2.717263  0.996590 -0.005984
# 7            0.0  0.520679  0.790209 -0.221518 -0.042419 -0.525673 -0.005984
# 8            0.0 -0.421298 -0.965830 -1.499216 -0.027410 -0.752212 -1.054221
# 9            0.0  0.270654  2.019136  0.392619 -0.743603  1.423034  0.850488
# 10           1.0 -0.912133  1.131420 -0.934319 -1.616539  1.308467 -1.054221
# ...

# %%
data = data.sample(n = 13760)

# %%
data[['f0']] = StandardScaler().fit_transform(data[['f0']])

# %%
data[['f1']] = StandardScaler().fit_transform(data[['f1']])

# %%
data[['f2']] = StandardScaler().fit_transform(data[['f2']])

# %%
data[['f3']] = StandardScaler().fit_transform(data[['f3']])

# %%
data[['f4']] = StandardScaler().fit_transform(data[['f4']])

# %%
data[['f5']] = StandardScaler().fit_transform(data[['f5']])

# %%
data[['f6']] = StandardScaler().fit_transform(data[['f6']])

# %%
data[['f7']] = StandardScaler().fit_transform(data[['f7']])

# %%
data[['f8']] = StandardScaler().fit_transform(data[['f8']])

# %%
data[['f9']] = StandardScaler().fit_transform(data[['f9']])

# %%
data[['f10']] = StandardScaler().fit_transform(data[['f10']])

# %%
data[['f11']] = StandardScaler().fit_transform(data[['f11']])

# %%
data[['f12']] = StandardScaler().fit_transform(data[['f12']])

# %%
data[['f13']] = StandardScaler().fit_transform(data[['f13']])

# %%
data[['f14']] = StandardScaler().fit_transform(data[['f14']])

# %%
data[['f15']] = StandardScaler().fit_transform(data[['f15']])

# %%
data[['f16']] = StandardScaler().fit_transform(data[['f16']])

# %%
data[['f17']] = StandardScaler().fit_transform(data[['f17']])

# %%
data[['f18']] = StandardScaler().fit_transform(data[['f18']])

# %%
data[['f19']] = StandardScaler().fit_transform(data[['f19']])

# %%
data[['f20']] = StandardScaler().fit_transform(data[['f20']])

# %%
data[['f21']] = StandardScaler().fit_transform(data[['f21']])

# %%
data[['f22']] = StandardScaler().fit_transform(data[['f22']])

# %%
data[['f23']] = StandardScaler().fit_transform(data[['f23']])

# %%
data[['f24']] = StandardScaler().fit_transform(data[['f24']])

# %%
data[['f25']] = StandardScaler().fit_transform(data[['f25']])

# %%
data[['f26']] = StandardScaler().fit_transform(data[['f26']])

# %%
data[['mass']] = StandardScaler().fit_transform(data[['mass']])

# %%
data.head()
# Out:
#          # label        f0        f1        f2        f3        f4        f5  \
# 2235754      1.0 -0.788123 -1.136031  0.818474 -0.125136 -0.075249 -0.006396
# 2273042      1.0 -0.611784  0.513035 -1.038206 -1.899544 -0.583238  0.846246
# 2077751      1.0 -1.154844 -1.052083 -1.633144  2.104251 -1.415705 -0.006396
# 869076       1.0  0.733164  0.074870  1.008850  1.465368  0.711604  0.846246
# 131142       0.0 -0.628150  0.052297 -0.354295 -1.117412  1.370897 -0.006396
#
#                f6        f7        f8    ...          f18       f19       f20  \
# 2235754 -0.255111 -0.106446  0.436628    ...     1.081813 -0.633192 -0.946061
# 2273042 -0.031003  0.767111  0.348768    ...     0.873058  0.440195 -0.309934
# 2077751  0.974142 -0.950507 -0.141845    ...     1.642451 -0.056600 -1.704029
# 869076   0.907838  1.113260 -1.381215    ...     1.248679  0.528903  0.546934
# 131142  -0.376265 -0.008421  0.136252    ...    -0.408148  0.956310 -1.555766
#
# ...

# %%
train = data.head(11008)

# %%
train.count()
# Out:
# # label    11008
# f0         11008
# f1         11008
# f2         11008
# f3         11008
# f4         11008
# f5         11008
# f6         11008
# f7         11008
# f8         11008
# f9         11008
# f10        11008
# f11        11008
# f12        11008
# f13        11008
# f14        11008
# f15        11008
# f16        11008
# f17        11008
# f18        11008
# f19        11008
# f20        11008
# f21        11008
# f22        11008
# f23        11008
# f24        11008
# f25        11008
# f26        11008
# mass       11008
# dtype: int64

# %%
test = data.tail(2752)

# %%
test.count()
# Out:
# # label    2752
# f0         2752
# f1         2752
# f2         2752
# f3         2752
# f4         2752
# f5         2752
# f6         2752
# f7         2752
# f8         2752
# f9         2752
# f10        2752
# f11        2752
# f12        2752
# f13        2752
# f14        2752
# f15        2752
# f16        2752
# f17        2752
# f18        2752
# f19        2752
# f20        2752
# f21        2752
# f22        2752
# f23        2752
# f24        2752
# f25        2752
# f26        2752
# mass       2752
# dtype: int64

# %%
train.to_csv('HEPMASS/train.csv', header = False, index = False)

# %%
test.to_csv('HEPMASS/test.csv', header = False, index = False)
